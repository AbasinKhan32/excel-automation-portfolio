# %%
# Merging them using the common column Roll No
import pandas as pd

students = pd.read_excel("students.xlsx")
marks = pd.read_excel("marks.xlsx")

merged_data = pd.merge(students, marks, on="Roll No")

print(merged_data)
# Out:
#    Roll No   Name Department  Marks
# 0        1   Ali          CS     85
# 1        2  Ahmad         IT     90

# %%
students.columns = students.columns.str.strip()
marks.columns = marks.columns.str.strip()

merged = pd.merge(students, marks, on="Roll No")
print(merged)
# Out:
#    Roll No   Name Department  Marks
# 0        1   Ali          CS     85
# 1        2  Ahmad         IT     90

# %%
import pandas as pd

students = pd.read_excel("students.xlsx")
marks = pd.read_excel("marks.xlsx")

# Remove extra spaces from column names
students.columns = students.columns.str.strip()
marks.columns = marks.columns.str.strip()

# Check column names
print(students.columns)
print(marks.columns)

# Merge the files
merged = pd.merge(students, marks, on="Roll No")

print(merged)
# Out:
# Index(['Roll No', 'Name', 'Department'], dtype='str')
# Index(['Roll No', 'Marks'], dtype='str')
#    Roll No   Name Department  Marks
# 0        1   Ali          CS     85
# 1        2  Ahmad         IT     90
