# %%
import pandas as pd

df = pd.read_excel("Students_Data.xlsx",
    sheet_name=["Students","Employees"]
    )
# students = df["Students"] #Printing Sheets Separately
# emp = df["Employees"]
# print(students)
# print(emp)
# Out:
#        Name  Age       Department
# 0    Faizan   19               CS
# 1   Mushtaq   20  Electrical Engr
# 2  Iftikhar   20       Civil Engr
# 3  Abdullah   21               CS
#         Name   Emp_ID  Salary
# 0      Ishfaq     546   40000
# 1    Ali Khan     298   65000
# 2  Ubaid Khan     478   55000
